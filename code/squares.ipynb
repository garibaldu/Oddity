# %% [markdown]
# It's a new notebook!

# %%
from astropy.io import fits
hdulist = fits.open('../data/frame-r-000094-1-0131.fits.gz')
bigimg = hdulist[0].data
img = bigimg[:256,:512]
gray()
imshow(img, origin='lower')

# %%
M = 8 # number of histogram bins
def intensity_to_m(img, M):
    ny, nx = img.shape
    N = ny*nx
    mimgvec = np.zeros(N,dtype=int)
    mimgvec[argsort(img.reshape(N))] = np.floor((float(M) / float(N)) * np.arange(N)).astype(int)
    return mimgvec.reshape((ny, nx))

imshow(intensity_to_m(img, M), interpolation='nearest', origin='lower')

# %%
def intensity_to_boolean_block(img, M):
    mimg = intensity_to_m(img, M)
    ny, nx = mimg.shape
    N = ny * nx
    bb = np.zeros((M, ny+1, nx+1),dtype=bool)
    for m in range(M):
        bb[m, 1:, 1:] = (mimg == m)
    return bb

imshow(intensity_to_boolean_block(img, M)[-1], origin='lower')

# %%
def intensity_to_cumulated_block(img, M):
    return np.cumsum(np.cumsum(intensity_to_boolean_block(img, M), axis=2), axis=1)

# %%
M=8
cbb = intensity_to_cumulated_block(img, M)
imshow(cbb[-1],  interpolation='nearest', origin='lower')

# %%
class OddityBB:
    def __init__(self, llc, width):
        """ Warning: this sets llc and width to be ints; truncation.
        """
        assert len(llc) == 2
        self.llc = np.array(llc, dtype=int)
        self.width = int(width)
    
    def _get_corners(self):
        """
        We're defining what we mean by corners here! 
        These are the 'corners' relevant to the output of intensity_to_cumulated_block.
        """
        return (self.llc,
                self.llc + [self.width, 0],
                self.llc + [self.width, self.width],
                self.llc + [0, self.width])
    
    def _get_cumulated_block_elt(self, pos, cumulated_block):
        M, nyplus1, nxplus1 = cumulated_block.shape
        cpos = np.clip(pos, [0, 0], [nyplus1-1, nxplus1-1])
        return cumulated_block[:, cpos[0], cpos[1]]
    
    def get_counts(self, cumulated_block):
        corners = self._get_corners()
        return (self._get_cumulated_block_elt(corners[0], cumulated_block)
                - self._get_cumulated_block_elt(corners[1], cumulated_block)
                + self._get_cumulated_block_elt(corners[2], cumulated_block)
                - self._get_cumulated_block_elt(corners[3], cumulated_block))

# %%
bb = OddityBB((-2,-2), 1000)
print bb._get_corners()
print bb.get_counts(cbb)
print bb.llc
print intensity_to_m(img, M)[:5,:4]
print np.where(img == np.max(img))
print OddityBB((150,41), 9).get_counts(cbb)
# Out:
# (array([-2, -2]), array([998,  -2]), array([998, 998]), array([ -2, 998]))
# [16384 16384 16384 16384 16384 16384 16384 16384]
# [-2 -2]
# [[3 7 4 4]
#  [0 5 1 4]
#  [0 1 5 3]
#  [5 2 1 1]
#  [1 4 2 5]]
# (array([152]), array([43]))
# [ 2  1  0  4  0  1  8 65]

# %% [markdown]
# The Dirichlet-multinomal distribution is
#
# $$ P(Z | \alpha) = \frac{\Gamma(\sum_m \alpha_m)}{\Gamma(\sum_m [n_m + \alpha_m])} \prod_{m=1}^M \frac{\Gamma(n_m + \alpha_m)}{\Gamma(\alpha_m)}  $$
#
# So its log is
#
# $$ \log P(Z | \alpha) = \log \Gamma(A) - \log \Gamma(N+A) \;\; +  \sum_{m=1}^M \big[ \log \Gamma(n_m + \alpha_m) - \log \Gamma(\alpha_m) \big]  $$
#
# and $\Gamma(z) = (z-1)!$ so $\log \Gamma(z) = \sum_{m=1}^{z-1} \log m$

# %%
Amax = 2 ** 21
global logGm
logGm = np.append(np.array([np.Inf, 0.]), np.cumsum(np.log(np.arange(Amax - 2) + 1)))
def gammaln(k):
    return logGm[k]

#Following lines are testing this out - we're accurate to 7th decimal at factorial(10^6) : TICK.
#from scipy.special import gammaln
#foo = 1000000
#print np.min(logGm[1:foo] - gammaln(np.arange(1, foo)))
#print np.max(logGm[1:foo] - gammaln(np.arange(1, foo)))

# %%
def get_logL(counts, alphas):
    """
    Takes a vector of counts (across bins), and vector of alpha hyperparameters (ditto).
    Returns the log likelihood of those counts under the Dirichlet-multinomial distribution with
    those hyperparameters.
    """
    # initialize internal (static) variables
    try:
        get_logL.Cmax
    except:
        get_logL.Cmax = 1
        get_logL.gammaln = np.array([np.Inf])
    N, A = np.sum(counts), np.sum(alphas)
    # calculate more lookup table if necessary
    if N + A > get_logL.Cmax:
        print "get_logL(): Calculating expensive lookup shit"
        get_logL.Cmax = 2 * (N + A)
        get_logL.gammaln = np.append(np.array([np.Inf, 0.]), np.cumsum(np.log(np.arange(get_logL.Cmax - 2) + 1)))
    # now the actual LF
    return (  get_logL.gammaln[A] 
            - get_logL.gammaln[N+A] 
            + np.sum( get_logL.gammaln[counts + alphas]) 
            - np.sum( get_logL.gammaln[alphas]) )


print get_logL(np.array([1,1,1]), 100*np.array([1,2,3]))
print get_logL(np.array([31,351,21]), 100*np.array([1,2,3]))
print get_logL(np.array([1000,10000,1000]), 100*np.array([1,2,3]))
# Out:
# get_logL(): Calculating expensive lookup shit
# -3.58851200787
# -356.010217835
# get_logL(): Calculating expensive lookup shit
# -7185.84482372

# %%
def get_full_logL(cumulated_block, BBs, alphas_S, alphas_B):
    """
    ## inputs
    - `BBs` is a list of `OddityBB` objects.
    """
    logL = 0.
    source_counts = 0
    for BB in BBs:
        this_counts = BB.get_counts(cumulated_block)
        logL += get_logL(this_counts, alphas_S)
        source_counts += this_counts
    background_counts = cumulated_block[:, -1, -1].ravel() - source_counts
    logL += get_logL(background_counts, alphas_B)
    return logL

# %%
ys, xs = np.mgrid[130:160,20:50]
params = [OddityBB(pos,7) for pos in zip(ys.ravel(), xs.ravel())]
logL_grid = np.zeros((30,30))
M, foo, bar = cbb.shape
for y,x,BB in zip(ys.ravel(), xs.ravel(), params):
    logL_grid[y-130,x-20] = get_full_logL(cbb, [BB, ], np.ones(M, dtype=int), np.ones(M, dtype=int)*int(30*30/M))
# Out:
# get_logL(): Calculating expensive lookup shit

# %%
imshow(logL_grid, interpolation='nearest', origin='lower')
logL_grid.min() - logL_grid.max()
# Out:
# -86.15481434436515
